# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\admin\anaconda3\lib\site-packages (4.9.1)
# Requirement already satisfied: trio~=0.17 in c:\users\admin\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\admin\anaconda3\lib\site-packages (from selenium) (0.10.2)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\admin\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\admin\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: sortedcontainers in c:\users\admin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\admin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: async-generator>=1.9 in c:\users\admin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sniffio in c:\users\admin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\admin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\admin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\admin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: outcome in c:\users\admin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\admin\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\admin\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\admin\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

# %%
start_date = pd.to_datetime('2023-06-01')
end_date = pd.to_datetime('2023-08-31')

data = []

for date in pd.date_range(start_date, end_date, freq='D'):
    search_url = f"https://m-flight.naver.com/flights/international/ICN-PAR-{date.strftime('%Y%m%d')}?adult=1&fareType=F"

    browser = webdriver.Chrome('C:/Users/chromedriver.exe')
    browser.get(search_url)
    browser.implicitly_wait(20)

    oneday = browser.find_elements(By.CLASS_NAME, "indivisual_inner__2RKYG")
    for i in range(len(oneday)):
        rr1 = oneday[i].find_element(By.CLASS_NAME, "indivisual_schedule__1tq7j").text
        rr2 = oneday[i].find_element(By.CLASS_NAME, "item_ItemPriceList__22YBo").text
        data.append([date, rr1, rr2])

    browser.quit()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_37176\2914014037.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome('C:/Users/chromedriver.exe')

# %%
df = pd.DataFrame(data, columns=['date', 'rr1', 'rr2'])

# %%
df
# Out:
#           date                                                rr1  \
# 0   2023-06-01  캐세이퍼시픽항공\n15:10ICN\n07:00CDG\n+1일\n경유 1, 22시간 50분
# 1   2023-06-01  캐세이퍼시픽항공\n10:10ICN\n07:00CDG\n+1일\n경유 1, 27시간 50분
# 2   2023-06-01  캐세이퍼시픽항공\n13:35ICN\n07:00CDG\n+1일\n경유 1, 24시간 25분
# 3   2023-06-01  캐세이퍼시픽항공\n20:15ICN\n07:00CDG\n+2일\n경유 1, 41시간 45분
# 4   2023-06-02   에미레이트항공\n23:55ICN\n13:30CDG\n+1일\n경유 1, 20시간 35분
# ..         ...                                                ...
# 788 2023-08-31  일본항공대한항공 공동운항\n18:05ICN\n16:15CDG\n+1일\n경유 1, ...
# 789 2023-08-31     여러항공사\n11:25ICN\n16:35ORY\n+1일\n경유 2, 36시간 10분
# 790 2023-08-31     여러항공사\n11:25ICN\n20:10ORY\n+1일\n경유 2, 39시간 45분
# 791 2023-08-31     여러항공사\n11:25ICN\n23:15CDG\n+1일\n경유 2, 42시간 50분
# 792 2023-08-31  여러항공사대한항공 공동운항\n20:30ICN\n23:15CDG\n+1일\n경유 2,...
#
#                                                 rr2
# 0                        성인/KB국민카드\n편도 10,938,100원~
# 1                        성인/KB국민카드\n편도 10,938,100원~
# 2                        성인/KB국민카드\n편도 10,938,100원~
# 3                        성인/KB국민카드\n편도 10,958,700원~
# 4    성인/현대 M2/M3 Edition2(이용실적 충족시)\n편도 5,843,900원~
# ..                                              ...
# 788                      성인/모든 결제수단\n편도 7,147,300원~
# 789                      성인/모든 결제수단\n편도 7,289,700원~
# 790                      성인/모든 결제수단\n편도 7,289,700원~
# 791                      성인/모든 결제수단\n편도 7,405,600원~
# 792                      성인/모든 결제수단\n편도 7,888,300원~
#
# [793 rows x 3 columns]

# %%
split0 = df[['date']]

# %%
split0.columns = ['Date']

# %%
split1 = df.rr1.str.split('\n', expand = True)
split1.columns = ['Airline', 'Departure', 'Arrival', 'Day', 'time']

# %%
split01 = pd.concat([split0, split1], axis = 1)

# %%
split2 = df.rr2.str.split('\n', expand = True)
split2.columns = ['Payment', 'Price']

# %%
split012 = pd.concat([split01, split2], axis = 1)

# %%
split012
# Out:
#           Date         Airline Departure   Arrival  Day            time  \
# 0   2023-06-01        캐세이퍼시픽항공  15:10ICN  07:00CDG  +1일  경유 1, 22시간 50분
# 1   2023-06-01        캐세이퍼시픽항공  10:10ICN  07:00CDG  +1일  경유 1, 27시간 50분
# 2   2023-06-01        캐세이퍼시픽항공  13:35ICN  07:00CDG  +1일  경유 1, 24시간 25분
# 3   2023-06-01        캐세이퍼시픽항공  20:15ICN  07:00CDG  +2일  경유 1, 41시간 45분
# 4   2023-06-02         에미레이트항공  23:55ICN  13:30CDG  +1일  경유 1, 20시간 35분
# ..         ...             ...       ...       ...  ...             ...
# 788 2023-08-31   일본항공대한항공 공동운항  18:05ICN  16:15CDG  +1일  경유 1, 29시간 10분
# 789 2023-08-31           여러항공사  11:25ICN  16:35ORY  +1일  경유 2, 36시간 10분
# 790 2023-08-31           여러항공사  11:25ICN  20:10ORY  +1일  경유 2, 39시간 45분
# 791 2023-08-31           여러항공사  11:25ICN  23:15CDG  +1일  경유 2, 42시간 50분
# 792 2023-08-31  여러항공사대한항공 공동운항  20:30ICN  23:15CDG  +1일  경유 2, 33시간 45분
#
#                             Payment            Price
# 0                         성인/KB국민카드  편도 10,938,100원~
# 1                         성인/KB국민카드  편도 10,938,100원~
# 2                         성인/KB국민카드  편도 10,938,100원~
# 3                         성인/KB국민카드  편도 10,958,700원~
# 4    성인/현대 M2/M3 Edition2(이용실적 충족시)   편도 5,843,900원~
# ..                              ...              ...
# 788                      성인/모든 결제수단   편도 7,147,300원~
# 789                      성인/모든 결제수단   편도 7,289,700원~
# 790                      성인/모든 결제수단   편도 7,289,700원~
# 791                      성인/모든 결제수단   편도 7,405,600원~
# 792                      성인/모든 결제수단   편도 7,888,300원~
#
# [793 rows x 8 columns]

# %%
split012.to_csv('airpar_FC.csv', index=False)
